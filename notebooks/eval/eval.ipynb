# %%
from pyevall.evaluation import PyEvALLEvaluation
from pyevall.utils.utils import PyEvALLUtils

# Path to your prediction and gold label files
predictions = "/Volumes/T7/OMSCS/CLEF2025/EXIST2025/exist-2025/notebooks/eval/EXIST2025_training_task3_1_majority_class_hard.json"
gold        = "/Volumes/T7/OMSCS/CLEF2025/EXIST2025/exist-2025/notebooks/eval/EXIST2025_training_task3_1_gold_hard.json"

# Create a PyEvALL evaluation object
test = PyEvALLEvaluation()

# Set evaluation parameters: here, ask for an embedded report
params = dict()
params[PyEvALLUtils.PARAM_REPORT] = PyEvALLUtils.PARAM_OPTION_REPORT_EMBEDDED

# List of metrics to evaluate
metrics = ["ICM", "ICMNorm", "FMeasure"]

# Run the evaluation
report = test.evaluate(predictions, gold, metrics, **params)

# Print the report
# Out:
# 2025-05-08 20:19:17,628 - pyevall.evaluation - INFO -             evaluate() - Evaluating the following metrics ['ICM', 'ICMNorm', 'FMeasure']
# 2025-05-08 20:19:17,775 - pyevall.metrics.metrics - INFO -             evaluate() - Executing ICM evaluation method
# 2025-05-08 20:19:18,170 - pyevall.metrics.metrics - INFO -             evaluate() - Executing ICM Normalized evaluation method
# 2025-05-08 20:19:18,171 - pyevall.metrics.metrics - INFO -             evaluate() - Executing ICM evaluation method
# 2025-05-08 20:19:18,567 - pyevall.metrics.metrics - INFO -             evaluate() - Executing ICM evaluation method
# 2025-05-08 20:19:18,961 - pyevall.metrics.metrics - INFO -             evaluate() - Executing fmeasure evaluation method
# {
#   "metrics": {
#     "ICM": {
#       "name": "Information Contrast model",
#       "acronym": "ICM",
#       "description": "Coming soon!",
#       "status": "OK",
#       "results": {
#         "test_cases": [{
#           "name": "EXIST2025",
#           "average": 0.9987592602683767
#         }],
#         "average_per_test_case": 0.9987592602683767
#       }
#     },
#     "ICMNorm": {
#       "name": "Normalized Information Contrast Model",
#       "acronym": "ICM-Norm",
#       "description": "Coming soon!",
#       "status": "OK",
#       "results": {
#         "test_cases": [{
#           "name": "EXIST2025",
#           "average": 1.0
#         }],
#         "average_per_test_case": 1.0
#       }
#     },
#     "FMeasure": {
#       "name": "F-Measure",
#       "acronym": "F1",
#       "description": "Coming soon!",
#       "status": "OK",
#       "results": {
#         "test_cases": [{
#           "name": "EXIST2025",
#           "classes": {
#             "YES": 1.0,
#             "NO": 1.0
#           },
#           "average": 1.0
#         }],
#         "average_per_test_case": 1.0
#       }
#     }
#   },
#   "files": {
#     "EXIST2025_training_task3_1_gold_hard.json": {
#       "name": "EXIST2025_training_task3_1_gold_hard.json",
#       "status": "OK",
#       "gold": false,
#       "description": "The file is correctly parser without errors or warnings.\\nFile name: EXIST2025_training_task3_1_gold_hard.json.",
#       "errors": {}
#     },
#     "EXIST2025_training_task3_1_gold_hard.json_duplicate_0": {
#       "name": "EXIST2025_training_task3_1_gold_hard.json",
#       "status": "OK",
#       "gold": true,
#       "description": "The file is correctly parser without errors or warnings.\\nFile name: EXIST2025_training_task3_1_gold_hard.json.",
#       "errors": {}
#     }
#   }
# }

# %%
report.print_report()
# Out:
# {
#   "metrics": {
#     "ICM": {
#       "name": "Information Contrast model",
#       "acronym": "ICM",
#       "description": "Coming soon!",
#       "status": "OK",
#       "results": {
#         "test_cases": [{
#           "name": "EXIST2025",
#           "average": 0.9987592602683767
#         }],
#         "average_per_test_case": 0.9987592602683767
#       }
#     },
#     "ICMNorm": {
#       "name": "Normalized Information Contrast Model",
#       "acronym": "ICM-Norm",
#       "description": "Coming soon!",
#       "status": "OK",
#       "results": {
#         "test_cases": [{
#           "name": "EXIST2025",
#           "average": 1.0
#         }],
#         "average_per_test_case": 1.0
#       }
#     },
#     "FMeasure": {
#       "name": "F-Measure",
#       "acronym": "F1",
#       "description": "Coming soon!",
#       "status": "OK",
#       "results": {
#         "test_cases": [{
#           "name": "EXIST2025",
#           "classes": {
#             "YES": 1.0,
#             "NO": 1.0
#           },
#           "average": 1.0
#         }],
#         "average_per_test_case": 1.0
#       }
#     }
#   },
#   "files": {
#     "EXIST2025_training_task3_1_gold_hard.json": {
#       "name": "EXIST2025_training_task3_1_gold_hard.json",
#       "status": "OK",
#       "gold": false,
#       "description": "The file is correctly parser without errors or warnings.\\nFile name: EXIST2025_training_task3_1_gold_hard.json.",
#       "errors": {}
#     },
#     "EXIST2025_training_task3_1_gold_hard.json_duplicate_0": {
#       "name": "EXIST2025_training_task3_1_gold_hard.json",
#       "status": "OK",
#       "gold": true,
#       "description": "The file is correctly parser without errors or warnings.\\nFile name: EXIST2025_training_task3_1_gold_hard.json.",
#       "errors": {}
#     }
#   }
# }
